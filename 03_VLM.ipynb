# %% [markdown]
# <a href="https://colab.research.google.com/github/nilaynishant/LLM_Course/blob/main/03_VLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geoai-py transformers==4.57.6 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 108.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.2/584.2 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.8/666.8 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 51.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 98.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.6/863.6 kB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 74.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 93.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 132.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 123.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.5/786.5 kB 65.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.7 MB/s eta 0:00:00

# %%
import geoai
import leafmap
from geoai import MoondreamGeo

# %%
url = "https://data.source.coop/opengeos/geoai/parking-lot.tif"
image_path = geoai.download_file(url)
# Out:
# Downloading parking-lot.tif: 100%|██████████| 4.46M/4.46M [00:00<00:00, 69.3MB/s]

# %%
m = leafmap.Map()
m.add_raster(image_path, layer_name="Satellite Image")
m
# Out:
# Map(center=[29.678521500000002, -95.42043100000001], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
processor = MoondreamGeo(
 model_name="vikhyatk/moondream2",
 revision="2025-06-21",
)
# Out:
# config.json:   0%|          | 0.00/277 [00:00<?, ?B/s]
# hf_moondream.py: 0.00B [00:00, ?B/s]
# config.py: 0.00B [00:00, ?B/s]
# image_crops.py: 0.00B [00:00, ?B/s]
# moondream.py: 0.00B [00:00, ?B/s]
# lora.py: 0.00B [00:00, ?B/s]
# layers.py: 0.00B [00:00, ?B/s]
# region.py: 0.00B [00:00, ?B/s]
# text.py: 0.00B [00:00, ?B/s]
# rope.py: 0.00B [00:00, ?B/s]
# vision.py: 0.00B [00:00, ?B/s]
# utils.py: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/69.0 [00:00<?, ?B/s]

# %%
result = processor.caption(image_path, length="short")
print(result["caption"])
# Out:
# An aerial view of a large parking lot reveals two white buildings, numerous parked cars, and a network of roads, all bathed in natural light.

# %%
result = processor.caption(image_path, length="normal")
print(result["caption"])
# Out:
# An aerial view showcases a complex of primarily warehouse-like structures, primarily light gray or white in color, with several parking lots scattered throughout.  A wide, paved road runs through the center, with multiple lanes of traffic. A single large tree is visible near the center-left of the image, providing a touch of green amidst the industrial landscape. The parking lots are filled with cars, indicating active human activity in the area. The aerial perspective showcases the intricate layout of the complex.

# %%
result = processor.caption(image_path, length="long")
print(result["caption"])
# Out:
# This aerial image shows a spacious parking lot area surrounded by two large buildings. The parking lot is divided into multiple sections by clearly marked parking spaces, roads, and pathways. The parking lots are filled with numerous cars, trucks, and vans of various sizes and colors, parked neatly in rows and columns. The buildings have flat, grey roofs and appear to have multiple levels or floors. The parking lot area is well-maintained and organized, with green spaces and trees placed strategically to enhance the aesthetics and offer shade. The image is captured from a high vantage point, providing a comprehensive overview of the parking lot layout, building structures, parking spaces, and surrounding environment.

# %%
result = processor.query("How many buildings are in the image?", image_path)
print(result["answer"])
# Out:
# There are two buildings in the image.

# %%
result = processor.query("How many trees are there in the image?", image_path)
print(result["answer"])
# Out:
# There are several trees in the image.
